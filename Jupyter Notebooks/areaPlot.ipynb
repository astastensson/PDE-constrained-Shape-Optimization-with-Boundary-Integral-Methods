# %%
from areaOpt import *

# %%
trueLoss = jnp.pi
nrOfQuadPoints = 4
a0, b0, t, w, ints = initiateEllipse(nrOfQuadPoints,10)

# %%
iterations, coffs, grads, diffs, areas, ts, ws = gradientDesc(a0, b0, t, w, nrOfQuadPoints)

# %%
plotConv(iterations, coffs)

# %%
plotGrads(iterations, coffs, grads)

# %%
plotPoints(iterations, coffs, ts)

# %%
plotErrorAndShape(iterations, coffs, areas, trueLoss)
